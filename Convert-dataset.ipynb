# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import json
import pandas as pd

# %%
data = []

for line in open('/content/drive/MyDrive/Soft Computing Project/Cell_Phones_and_Accessories_5.json','r') :
    data.append(json.loads(line))

# %%
print(data[0])
df = pd.DataFrame(data)
print(len(data))
# Out:
# {'reviewerID': 'A30TL5EWN6DFXT', 'asin': '120401325X', 'reviewerName': 'christina', 'helpful': [0, 0], 'reviewText': "They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again", 'overall': 4.0, 'summary': 'Looks Good', 'unixReviewTime': 1400630400, 'reviewTime': '05 21, 2014'}
# 194439

# %%
df = df.drop(columns=['reviewerName'])
df1 = df.rename(columns = {'overall': 'rating', 'asin': 'productID'}, inplace = False)

# %%
df1.dropna(axis = 0, how ='any',inplace=True) 
df1.drop_duplicates(subset=['rating','reviewText'],keep='first',inplace=True)

# %%
print(len(df1))
df1.to_csv('Dataset.csv')
# Out:
# 194226

# %%
df1
# Out:
#             reviewerID   productID  ... unixReviewTime   reviewTime
# 0       A30TL5EWN6DFXT  120401325X  ...     1400630400  05 21, 2014
# 1        ASY55RVNIL0UD  120401325X  ...     1389657600  01 14, 2014
# 2       A2TMXE2AFO7ONB  120401325X  ...     1403740800  06 26, 2014
# 3        AWJ0WZQYMYFQ4  120401325X  ...     1382313600  10 21, 2013
# 4        ATX7CZYFXI1KW  120401325X  ...     1359849600   02 3, 2013
# ...                ...         ...  ...            ...          ...
# 194434  A1YMNTFLNDYQ1F  B00LORXVUE  ...     1405900800  07 21, 2014
# 194435  A15TX8B2L8B20S  B00LORXVUE  ...     1405900800  07 21, 2014
# 194436  A3JI7QRZO1QG8X  B00LORXVUE  ...     1405900800  07 21, 2014
# 194437  A1NHB2VC68YQNM  B00LORXVUE  ...     1405814400  07 20, 2014
# 194438  A1AG6U022WHXBF  B00LORXVUE  ...     1405900800  07 21, 2014
#
# [194226 rows x 8 columns]
